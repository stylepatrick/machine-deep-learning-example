# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15155, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15155 (delta 7), reused 9 (delta 3), pack-reused 15138
# Receiving objects: 100% (15155/15155), 14.15 MiB | 9.33 MiB/s, done.
# Resolving deltas: 100% (10385/10385), done.
# /content/yolov5/yolov5

# %% [markdown]
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
from PIL import Image, ImageDraw
from google.colab import drive 
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive
# benchmarks.py	 detect.py   __pycache__       segment	       val.py
# CITATION.cff	 export.py   README.md	       setup.cfg       yolov5s.pt
# classify	 hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data		 models      runs	       utils

# %%
img = Image.open("/content/drive/MyDrive/NeuralNetwork/bild2.jpg");
# Out:
# <PIL.Image.Image image mode=RGB size=648x432 at 0x7FA67E4F07C0>

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/NeuralNetwork/bild2.jpg
display.Image(filename='runs/detect/exp16/bild2.jpg', width=600)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
